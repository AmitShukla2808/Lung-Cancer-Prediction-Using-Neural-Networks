# %% [markdown]
# # Prediction Of Lung Cancer Using Deep Learning Model

# %% [markdown]
# The following project makes use of simple Neural Networks to predict chances of a person having lung cancer or not. Lung cancer is a major problem in many countries, especially India due to high rate of consumption of tobacco products like cigarettes, cigars, alcohol etc. Its important to focus on this problem and develop a system to control tobacco consumption. The source of the dataset is : https://www.kaggle.com/datasets/yusufdede/lung-cancer-dataset

# %%
# Importing useful libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras import Sequential
import seaborn as sns

# %%
# Importing dataset

lung_cancer_data = pd.read_csv('lung_cancer_examples.csv')

# %%
lung_cancer_data.head()
# Out:
#      Name      Surname  Age  Smokes  AreaQ  Alkhol  Result
# 0    John         Wick   35       3      5       4       1
# 1    John  Constantine   27      20      2       5       1
# 2  Camela     Anderson   30       0      5       2       0
# 3    Alex       Telles   28       0      8       1       0
# 4   Diego     Maradona   68       4      5       6       1

# %% [markdown]
# The data here is not very large and number of features that we are going to use, is also less. The 4 features we will talk about are Age, Smokes, Air Quality Index and alcohol consumption. Lets first dive into some analysis of the data.

# %%
plt.figure(figsize=(10,8))
Y = lung_cancer_data['Result']
del lung_cancer_data['Result']
del lung_cancer_data['Name']
del lung_cancer_data['Surname']
X = lung_cancer_data
sns.heatmap(lung_cancer_data.corr())

# %% [markdown]
# We can see that smokes and alcohol have a decent amount of correlation which shows that both of these activities are usually accompanied by one another. A interesting thing to see is that smokes and alcohol also has a good amount of correlation with age which tends to see that these things are also dependent on age group we are talking about. Lets see the count of people who have cancer and who dont have it !

# %%
X
# Out:
#     Age  Smokes  AreaQ  Alkhol
# 0    35       3      5       4
# 1    27      20      2       5
# 2    30       0      5       2
# 3    28       0      8       1
# 4    68       4      5       6
# 5    34       0     10       0
# 6    58      15     10       0
# 7    22      12      5       2
# 8    45       2      6       0
# 9    52      18      4       5
# 10   33       4      8       0
# 11   18      10      6       3
# 12   25       2      5       1
# 13   28      20      2       8
# 14   34      25      4       8
# 15   39      18      8       1
# 16   42      22      3       5
# 17   19      12      8       0
# 18   62       5      4       3
# 19   73      10      7       6
# 20   55      15      1       3
# 21   33       8      8       1
# 22   22      20      6       2
# 23   44       5      8       1
# 24   77       3      2       6
# 25   21      20      5       3
# 26   37      15      6       2
# 27   34      12      8       0
# 28   55      20      1       4
# ...

# %%
Y
# Out:
# 0     1
# 1     1
# 2     0
# 3     0
# 4     1
# 5     0
# 6     0
# 7     0
# 8     0
# 9     1
# 10    0
# 11    0
# 12    0
# 13    1
# 14    1
# 15    0
# 16    1
# 17    0
# 18    1
# 19    1
# 20    1
# 21    0
# 22    0
# 23    0
# 24    1
# 25    0
# 26    0
# 27    0
# 28    1
# 29    1
# 30    0
# 31    1
# 32    1
# 33    1
# 34    0
# 35    0
# 36    1
# 37    1
# 38    0
# 39    0
# 40    1
# 41    0
# 42    1
# 43    1
# 44    0
# 45    0
# 46    0
# 47    0
# 48    1
# 49    1
# 50    0
# 51    1
# 52    1
# 53    0
# 54    0
# 55    1
# 56    1
# 57    1
# 58    0
# Name: Result, dtype: int64

# %%
model_predict_cancer = Sequential([Dense(units = 10,activation = 'relu'),Dense(units = 5,activation = 'relu'),Dense(units = 1,activation = 'sigmoid')])

# %%
from tensorflow.keras.losses import BinaryCrossentropy
model_predict_cancer.compile(loss='BinaryCrossentropy')

# %%
model_predict_cancer.fit(X,Y,epochs=150)
# Out:
# Epoch 1/150
# 2/2 [==============================] - 1s 7ms/step - loss: 3.4715
# Epoch 2/150
# 2/2 [==============================] - 0s 5ms/step - loss: 3.1212
# Epoch 3/150
# 2/2 [==============================] - 0s 7ms/step - loss: 2.8882
# Epoch 4/150
# 2/2 [==============================] - 0s 408ms/step - loss: 2.6986
# Epoch 5/150
# 2/2 [==============================] - 0s 6ms/step - loss: 2.5315
# Epoch 6/150
# 2/2 [==============================] - 0s 15ms/step - loss: 2.3812
# Epoch 7/150
# 2/2 [==============================] - 0s 8ms/step - loss: 2.2432
# Epoch 8/150
# 2/2 [==============================] - 0s 5ms/step - loss: 2.1133
# Epoch 9/150
# 2/2 [==============================] - 0s 5ms/step - loss: 1.9896
# Epoch 10/150
# 2/2 [==============================] - 0s 4ms/step - loss: 1.8725
# Epoch 11/150
# 2/2 [==============================] - 0s 5ms/step - loss: 1.7691
# Epoch 12/150
# 2/2 [==============================] - 0s 10ms/step - loss: 1.6673
# ...

# %%
model_predict_cancer.summary()
# Out:
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_69 (Dense)            (None, 10)                50
#
#  dense_70 (Dense)            (None, 5)                 55
#
#  dense_71 (Dense)            (None, 1)                 6
#
# ...
# Total params: 111
# Trainable params: 111
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_predict_cancer.weights
# Out:
# [<tf.Variable 'dense_69/kernel:0' shape=(4, 10) dtype=float32, numpy=
#  array([[ 0.1514527 ,  0.13256367,  0.5080874 ,  0.4520867 ,  0.19609386,
#           0.38851237,  0.6729734 , -0.18146236,  0.35096005, -0.23055732],
#         [ 0.454044  ,  0.05017048,  0.2690999 ,  0.03536077, -0.3165229 ,
#           0.31354475, -0.01890313, -0.31609958, -0.29691368, -0.41889006],
#         [ 0.4420446 ,  0.7064831 , -0.40479982,  0.27202392, -0.09311824,
#           0.07686409, -0.1368612 ,  0.5734038 ,  0.8241192 , -0.45244873],
#         [ 0.78641105, -0.71009773,  0.70614547, -0.19893326,  0.2778072 ,
#           0.24113853, -0.02905495,  0.49921888,  0.47593278,  0.09300888]],
#        dtype=float32)>,
#  <tf.Variable 'dense_69/bias:0' shape=(10,) dtype=float32, numpy=
#  array([-0.12348246,  0.11099064, -0.13973682,  0.11284701, -0.06351153,
#          0.10014972, -0.10563627, -0.05176344,  0.14487778,  0.        ],
#        dtype=float32)>,
# ...

# %%
predictions = model_predict_cancer.predict(X)
# Out:
# 2/2 [==============================] - 0s 5ms/step

# %%
predictions
# Out:
# array([[0.6071218 ],
#        [0.9202897 ],
#        [0.23132543],
#        [0.07354674],
#        [0.98966336],
#        [0.04668647],
#        [0.00536492],
#        [0.08596157],
#        [0.09838019],
#        [0.9464348 ],
#        [0.03183929],
#        [0.05362295],
#        [0.09407873],
#        [0.98921156],
#        [0.9539587 ],
#        [0.01089184],
#        [0.94023985],
#        [0.00893146],
#        [0.94895536],
#        [0.9502017 ],
#        [0.99038184],
#        [0.01326465],
#        [0.04122328],
#        [0.02753148],
#        [0.99969226],
#        [0.1539221 ],
#        [0.10968347],
#        [0.00604433],
#        [0.9939334 ],
#        [0.9925337 ],
#        [0.2318643 ],
#        [0.93799174],
#        [0.9992942 ],
#        [0.9758171 ],
#        [0.02304547],
#        [0.00833368],
#        [0.97434056],
#        [0.95018256],
#        [0.01358926],
#        [0.41796216],
#        [0.97735745],
#        [0.01413645],
#        [0.93652564],
# ...

# %%
for i in range(np.size(predictions)):
    if predictions[i]>=0.50:
        predictions[i] = 1
    else :
        predictions[i] = 0

# %%
total = np.size(predictions)
correct = 0
for i in range(total):
    if Y[i]==predictions[i]:
        correct+=1
print('Accuracy Of The Model : ', (correct/total)*100.00,"%")
# Out:
# Accuracy Of The Model :  98.30508474576271 %

# %% [markdown]
# We can see that our model has very efficiently calculated the predictions. With this we come to the end of this project.

# %% [markdown]
# # THANK YOU
